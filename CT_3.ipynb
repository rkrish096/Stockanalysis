# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import datetime
from datetime import datetime, timedelta
from matplotlib import dates as mpl_dates
plt.style.use('seaborn')
import scipy.stats as stats

# %%
data_1 = pd.read_csv("American_Airline.csv")
data_2 = pd.read_csv("Delta_Airline.csv")
data_3 = pd.read_csv("Jet_Blue.csv")
data_4 = pd.read_csv("United_Airline.csv")
data_1
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    02-01-2019  31.459999  32.650002  31.049999  32.480000  31.963156
# 1    03-01-2019  31.690001  31.850000  28.809999  30.059999  29.581663
# 2    04-01-2019  30.440001  32.090000  30.400000  32.040001  31.530159
# 3    07-01-2019  31.990000  33.480000  31.240000  32.950001  32.425678
# 4    08-01-2019  33.360001  33.650002  32.200001  32.419998  31.904114
# ..          ...        ...        ...        ...        ...        ...
# 751  23-12-2021  18.590000  18.719999  18.150000  18.260000  18.260000
# 752  27-12-2021  17.660000  18.240000  17.549999  18.170000  18.170000
# 753  28-12-2021  18.030001  18.639999  17.920000  18.540001  18.540001
# 754  29-12-2021  18.400000  18.430000  17.990000  18.049999  18.049999
# 755  30-12-2021  17.980000  18.379999  17.959999  18.070000  18.070000
#
#        Volume
# 0     5229500
# 1    16822000
# 2     9369600
# 3     8010700
# 4     7107700
# ..        ...
# ...

# %%
data_1 = data_1.rename(columns={'Close': 'American_Airline_Close'})
data_1
# Out:
#            Date       Open       High        Low  American_Airline_Close  \
# 0    02-01-2019  31.459999  32.650002  31.049999               32.480000
# 1    03-01-2019  31.690001  31.850000  28.809999               30.059999
# 2    04-01-2019  30.440001  32.090000  30.400000               32.040001
# 3    07-01-2019  31.990000  33.480000  31.240000               32.950001
# 4    08-01-2019  33.360001  33.650002  32.200001               32.419998
# ..          ...        ...        ...        ...                     ...
# 751  23-12-2021  18.590000  18.719999  18.150000               18.260000
# 752  27-12-2021  17.660000  18.240000  17.549999               18.170000
# 753  28-12-2021  18.030001  18.639999  17.920000               18.540001
# 754  29-12-2021  18.400000  18.430000  17.990000               18.049999
# 755  30-12-2021  17.980000  18.379999  17.959999               18.070000
#
#      Adj Close    Volume
# 0    31.963156   5229500
# 1    29.581663  16822000
# ...

# %%
# Add a Column to a DataFrame From Another DataFrame Pandas

data_1['Delta_Close'] = data_2['Close']

data_1['Jet_Blue_Close'] = data_3['Close']
data_1['United_Airline_Close'] = data_4['Close']
data_1
# Out:
#            Date       Open       High        Low  American_Airline_Close  \
# 0    02-01-2019  31.459999  32.650002  31.049999               32.480000
# 1    03-01-2019  31.690001  31.850000  28.809999               30.059999
# 2    04-01-2019  30.440001  32.090000  30.400000               32.040001
# 3    07-01-2019  31.990000  33.480000  31.240000               32.950001
# 4    08-01-2019  33.360001  33.650002  32.200001               32.419998
# ..          ...        ...        ...        ...                     ...
# 751  23-12-2021  18.590000  18.719999  18.150000               18.260000
# 752  27-12-2021  17.660000  18.240000  17.549999               18.170000
# 753  28-12-2021  18.030001  18.639999  17.920000               18.540001
# 754  29-12-2021  18.400000  18.430000  17.990000               18.049999
# 755  30-12-2021  17.980000  18.379999  17.959999               18.070000
#
#      Adj Close    Volume  Delta_Close  Jet_Blue_Close  United_Airline_Close
# ...

# %%
#Time_series = data_1.filter(['Close']),data_2.filter(['Close']),data_3.filter(['Close']),data_4.filter(['Close'])
#Time_series = data_1.filter(['American_Airline_Close'],['Delta_Close'],['Jet_Blue_Close'],['United_Airline_Close'])
#Time_series

TimeSeries = data_1.filter(['American_Airline_Close','Delta_Close','Jet_Blue_Close','United_Airline_Close'])
TimeSeries
# Out:
#      American_Airline_Close  Delta_Close  Jet_Blue_Close  United_Airline_Close
# 0                 32.480000    50.090000       16.200001             84.180000
# 1                 30.059999    45.610001       15.930000             80.000000
# 2                 32.040001    47.790001       16.549999             82.680000
# 3                 32.950001    47.849998       16.690001             83.230003
# 4                 32.419998    47.470001       16.850000             82.379997
# ..                      ...          ...             ...                   ...
# 751               18.260000    39.299999       14.670000             44.869999
# 752               18.170000    39.000000       14.560000             44.580002
# 753               18.540001    39.630001       14.680000             45.270000
# 754               18.049999    39.160000       14.380000             44.430000
# 755               18.070000    39.040001       14.240000             44.130001
#
# [756 rows x 4 columns]

# %% [markdown]
# # Plot the Time Series

# %%
TimeSeries.plot(figsize=(25,7))
plt.show()

# %%
#df['log_ret'] = np.log(df.Date) - np.log(df.price.shift(1))
#['pct_change'] = TimeSeries.American_Airline_Close.pct_change()
TimeSeries['LogReturn_American_Airline'] = np.log(TimeSeries['American_Airline_Close']/TimeSeries['American_Airline_Close'].shift(1))
TimeSeries
#TimeSeries[['pct_change', 'Log Return']].plot();
# Out:
#      American_Airline_Close  Delta_Close  Jet_Blue_Close  \
# 0                 32.480000    50.090000       16.200001
# 1                 30.059999    45.610001       15.930000
# 2                 32.040001    47.790001       16.549999
# 3                 32.950001    47.849998       16.690001
# 4                 32.419998    47.470001       16.850000
# ..                      ...          ...             ...
# 751               18.260000    39.299999       14.670000
# 752               18.170000    39.000000       14.560000
# 753               18.540001    39.630001       14.680000
# 754               18.049999    39.160000       14.380000
# 755               18.070000    39.040001       14.240000
#
#      United_Airline_Close  LogReturn_American_Airline
# 0               84.180000                         NaN
# 1               80.000000                   -0.077429
# 2               82.680000                    0.063790
# 3               83.230003                    0.028006
# ...

# %%
TimeSeries['Delta_Log_Return'] = np.log(TimeSeries['Delta_Close']/TimeSeries['Delta_Close'].shift(1))
TimeSeries
# Out:
#      American_Airline_Close  Delta_Close  Jet_Blue_Close  \
# 0                 32.480000    50.090000       16.200001
# 1                 30.059999    45.610001       15.930000
# 2                 32.040001    47.790001       16.549999
# 3                 32.950001    47.849998       16.690001
# 4                 32.419998    47.470001       16.850000
# ..                      ...          ...             ...
# 751               18.260000    39.299999       14.670000
# 752               18.170000    39.000000       14.560000
# 753               18.540001    39.630001       14.680000
# 754               18.049999    39.160000       14.380000
# 755               18.070000    39.040001       14.240000
#
#      United_Airline_Close  LogReturn_American_Airline  Delta_Log_Return
# 0               84.180000                         NaN               NaN
# 1               80.000000                   -0.077429         -0.093694
# ...

# %%
TimeSeries['Jet_Blue_Log Return'] = np.log(TimeSeries['Jet_Blue_Close']/TimeSeries['Jet_Blue_Close'].shift(1))
TimeSeries
# Out:
#      American_Airline_Close  Delta_Close  Jet_Blue_Close  \
# 0                 32.480000    50.090000       16.200001
# 1                 30.059999    45.610001       15.930000
# 2                 32.040001    47.790001       16.549999
# 3                 32.950001    47.849998       16.690001
# 4                 32.419998    47.470001       16.850000
# ..                      ...          ...             ...
# 751               18.260000    39.299999       14.670000
# 752               18.170000    39.000000       14.560000
# 753               18.540001    39.630001       14.680000
# 754               18.049999    39.160000       14.380000
# 755               18.070000    39.040001       14.240000
#
#      United_Airline_Close  LogReturn_American_Airline  Delta_Log_Return  \
# 0               84.180000                         NaN               NaN
# 1               80.000000                   -0.077429         -0.093694
# ...

# %%
TimeSeries['United_Airline_Log Return'] = np.log(TimeSeries['United_Airline_Close']/TimeSeries['United_Airline_Close'].shift(1))
TimeSeries
# Out:
#      American_Airline_Close  Delta_Close  Jet_Blue_Close  \
# 0                 32.480000    50.090000       16.200001
# 1                 30.059999    45.610001       15.930000
# 2                 32.040001    47.790001       16.549999
# 3                 32.950001    47.849998       16.690001
# 4                 32.419998    47.470001       16.850000
# ..                      ...          ...             ...
# 751               18.260000    39.299999       14.670000
# 752               18.170000    39.000000       14.560000
# 753               18.540001    39.630001       14.680000
# 754               18.049999    39.160000       14.380000
# 755               18.070000    39.040001       14.240000
#
#      United_Airline_Close  LogReturn_American_Airline  Delta_Log_Return  \
# 0               84.180000                         NaN               NaN
# 1               80.000000                   -0.077429         -0.093694
# ...

# %% [markdown]
# # LOG RETURN

# %%
TimeSeries2 = TimeSeries.filter(['Date','LogReturn_American_Airline','Delta_Log_Return','Jet_Blue_Log Return','United_Airline_Log Return'])

TimeSeries2
# Out:
#      LogReturn_American_Airline  Delta_Log_Return  Jet_Blue_Log Return  \
# 0                           NaN               NaN                  NaN
# 1                     -0.077429         -0.093694            -0.016807
# 2                      0.063790          0.046689             0.038182
# 3                      0.028006          0.001255             0.008424
# 4                     -0.016216         -0.007973             0.009541
# ..                          ...               ...                  ...
# 751                    0.000000          0.004335             0.002047
# 752                   -0.004941         -0.007663            -0.007527
# 753                    0.020159          0.016025             0.008208
# 754                   -0.026785         -0.011931            -0.020648
# 755                    0.001107         -0.003069            -0.009783
#
#      United_Airline_Log Return
# 0                          NaN
# 1                    -0.050931
# ...

# %% [markdown]
# Converting into text file from Log value

# %%
TimeSeries2.to_csv(r'd:\TimeSeries2.txt', header=None, index=None, sep='\t', mode='a')

# %%
mean = Log1.mean()
Cov = Log1.cov()
Sd = TimeSeries2.std()
mean.plot()
plt.title("Mean_values")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-31c013c6067e> in <module>
# ----> 1 mean = Log1.mean()
#       2 Cov = Log1.cov()
#       3 Sd = TimeSeries2.std()
#       4 mean.plot()
#       5 plt.title("Mean_values")
#
# NameError: name 'Log1' is not defined

# %%
Mean_1 = pd.DataFrame({
    'mean': [-0.0007, -0.0003, -0.0001, -0.0008],
    'std': [0.042578, 0.033734, 0.036061, 0.042278]})
Mean_1

# %%
Mean_1.plot()
plt.show()

# %%
#TimeSeries2.plot(figsize=(8,5))
#plt.show()

TimeSeries2[['United_Airline_Log Return']].plot(figsize=(8,5));

#plt.plot(TimeSeries2.Date, TimeSeries2.LogReturn_American_Airline, linewidth=3)
#plt.show

# %%
#TimeSeries2 ['Date'] = pd.to_datetime(TimeSeries2['Date'])
#TimeSeries2.sort_values('Date', inplace=True)

# %% [markdown]
# x = TimeSeries2['Date']
# y = TimeSeries2[{'LogReturn_American_Airline','Delta_Log_Return'}]
# plt.plot_date(x, y,linestyle='solid')
#
# plt.gcf().autofmt_xdate()
# date_format = mpl_dates.DateFormatter('%d-%m-%Y')
# plt.gca().xaxis.set_major_formatter(date_format)
# plt.tight_layout()
#
# plt.show()

# %%
TimeSeries2.dropna()

# %% [markdown]
# # Z SCORE

# %%
# Zscore

Z_score = TimeSeries2[['American_Airline_zscore','Delta_zscore','Jet_Blue_zscore','United_Airline_zscore']] = stats.zscore(TimeSeries2[{'LogReturn_American_Airline','Delta_Log_Return','Jet_Blue_Log Return','United_Airline_Log Return'}],nan_policy='omit')

TimeSeries2
# Out:
#      LogReturn_American_Airline  Delta_Log_Return  Jet_Blue_Log Return  \
# 0                           NaN               NaN                  NaN
# 1                     -0.077429         -0.093694            -0.016807
# 2                      0.063790          0.046689             0.038182
# 3                      0.028006          0.001255             0.008424
# 4                     -0.016216         -0.007973             0.009541
# ..                          ...               ...                  ...
# 751                    0.000000          0.004335             0.002047
# 752                   -0.004941         -0.007663            -0.007527
# 753                    0.020159          0.016025             0.008208
# 754                   -0.026785         -0.011931            -0.020648
# 755                    0.001107         -0.003069            -0.009783
#
#      United_Airline_Log Return  American_Airline_zscore  Delta_zscore  \
# ...

# %%
## TimeSeries3----- Zscore Dataframe

TimeSeries3 = TimeSeries2.filter(['American_Airline_zscore','Delta_zscore','Jet_Blue_zscore','United_Airline_zscore'])
Time =TimeSeries3.dropna()
Time
# Out:
#      American_Airline_zscore  Delta_zscore  Jet_Blue_zscore  \
# 1                  -0.461642     -1.801497        -1.185222
# 2                   1.064247      1.517449         0.800158
# 3                   0.238490      0.676457         0.177174
# 4                   0.269488     -0.362854        -0.222720
# 5                   0.623579      0.732224         0.413454
# ..                       ...           ...              ...
# 751                 0.061544      0.018253         0.179026
# 752                -0.204114     -0.097871        -0.133223
# 753                 0.232502      0.492026         0.383779
# 754                -0.568211     -0.611251        -0.423062
# 755                -0.266741      0.044281        -0.140112
#
#      United_Airline_zscore
# 1                -2.769467
# 2                 1.394742
# 3                 0.047009
# 4                -0.226715
# 5                 0.628181
# ..                     ...
# 751               0.138382
# ...

# %%
#TimeSeries3.plot(figsize=(25,10))
#plt.show()

#plt.hist(TimeSeries3)

TimeSeries3['United_Airline_zscore'].plot(figsize=(25,5))
plt.title('United_Airline_zscore')
plt.show()

# %%
TimeSeries2.head()
Log =TimeSeries2.filter(['Date','LogReturn_American_Airline','Delta_Log_Return','Jet_Blue_Log Return','United_Airline_Log Return'])
#TimeSeries3.dropna()
Log1= Log.dropna()
Log1
# Out:
#      LogReturn_American_Airline  Delta_Log_Return  Jet_Blue_Log Return  \
# 1                     -0.077429         -0.093694            -0.016807
# 2                      0.063790          0.046689             0.038182
# 3                      0.028006          0.001255             0.008424
# 4                     -0.016216         -0.007973             0.009541
# 5                      0.030379          0.020847             0.022301
# ..                          ...               ...                  ...
# 751                    0.000000          0.004335             0.002047
# 752                   -0.004941         -0.007663            -0.007527
# 753                    0.020159          0.016025             0.008208
# 754                   -0.026785         -0.011931            -0.020648
# 755                    0.001107         -0.003069            -0.009783
#
#      United_Airline_Log Return
# 1                    -0.050931
# 2                     0.032951
# ...

# %%
Log.to_csv(r'd:\log_return.txt', header=None, index=None, sep='\t', mode='a')

# %% [markdown]
# # Segmentation

# %%
from matplotlib.pylab import gca, figure, plot, subplot, title, xlabel, ylabel, xlim,show
from matplotlib.lines import Line2D
from numpy import arange, array,ones
from numpy.linalg import lstsq

# %%
from matplotlib.pylab import gca, figure, plot, subplot, title, xlabel, ylabel, xlim,show
from matplotlib.lines import Line2D
from numpy import arange, array,ones
from numpy.linalg import lstsq

# %%
#DEFINING A FUNCTION TO COMPUTE BOTTOMUPSEGMENT FOR TIME SERIES DATA

def bottomupsegment(sequence, create_segment, compute_error, max_error):

    segments = [create_segment(sequence,seq_range) for seq_range in zip(range(len(sequence))[:-1],range(len(sequence))[1:])]
    mergesegments = [create_segment(sequence,(seg1[0],seg2[2])) for seg1,seg2 in zip(segments[:-1],segments[1:])]
    mergecosts = [compute_error(sequence,segment) for segment in mergesegments]

    while min(mergecosts) < max_error:
        idx = mergecosts.index(min(mergecosts))
        segments[idx] = mergesegments[idx]
        del segments[idx+1]

        if idx > 0:
            mergesegments[idx-1] = create_segment(sequence,(segments[idx-1][0],segments[idx][2]))
            mergecosts[idx-1] = compute_error(sequence,mergesegments[idx-1])

        if idx+1 < len(mergecosts):
            mergesegments[idx+1] = create_segment(sequence,(segments[idx][0],segments[idx+1][2]))
            mergecosts[idx+1] = compute_error(sequence,mergesegments[idx])

        del mergesegments[idx]
        del mergecosts[idx]

    return segments

# %%
def leastsquareslinefit(sequence,seq_range):
    """Return the parameters and error for a least squares line fit of one segment of a sequence"""
    x = arange(seq_range[0],seq_range[1]+1)
    y = array(sequence[seq_range[0]:seq_range[1]+1])
    A = ones((len(x),2),float)
    A[:,0] = x
    (p,residuals,rank,s) = lstsq(A,y)
    try:
        error = residuals[0]
    except IndexError:
        error = 0.0
    return (p,error)

# %%
def sumsquared_error(sequence, segment):
    """Return the sum of squared errors for a least squares line fit of one segment of a sequence"""
    x0,y0,x1,y1 = segment
    p, error = leastsquareslinefit(sequence,(x0,x1))
    return error

# %%
def regression(sequence, seq_range):
    """Return (x0,y0,x1,y1) of a line fit to a segment of a sequence using linear regression"""
    p, error = leastsquareslinefit(sequence,seq_range)
    y0 = p[0]*seq_range[0] + p[1]
    y1 = p[0]*seq_range[1] + p[1]
    return (seq_range[0],y0,seq_range[1],y1)

# %%
def draw_plot(data,plot_title):
    plot(range(len(data)),data,alpha=0.8,color='red')
    title(plot_title)
    #xlabel("Samples")
    #ylabel("Signal")
    xlim((0,len(data)-1))

# %%
def draw_segments(segments):
    ax = gca()
    for segment in segments:
        line = Line2D((segment[0],segment[2]),(segment[1],segment[3]))
        ax.add_line(line)

# %% [markdown]
# # American_Airline_Error_Tolerance Level

# %%
max_error = 0.04

# %%
segments = bottomupsegment(Log1['LogReturn_American_Airline'], regression,sumsquared_error, max_error)
draw_plot(Log1['LogReturn_American_Airline'],"American_Airline_Error_Tolerance Level of 0.04%")
draw_segments(segments)
# Out:
# <ipython-input-24-794041481bfc>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   (p,residuals,rank,s) = lstsq(A,y)

# %%
max_error = 0.1

# %%
segments = bottomupsegment(Log1['LogReturn_American_Airline'], regression,sumsquared_error, max_error)
draw_plot(Log1['LogReturn_American_Airline'],"American_Airline_Error_Tolerance Level of 0.1%")
draw_segments(segments)
# Out:
# <ipython-input-24-794041481bfc>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   (p,residuals,rank,s) = lstsq(A,y)

# %%
max_error = 0.25

# %%
segments = bottomupsegment(Log1['LogReturn_American_Airline'], regression,sumsquared_error, max_error)
draw_plot(Log1['LogReturn_American_Airline'],"American_Airline_Error_Tolerance Level of 0.25%")
draw_segments(segments)
# Out:
# <ipython-input-24-794041481bfc>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   (p,residuals,rank,s) = lstsq(A,y)

# %% [markdown]
# # Delta_Log_Return_Error_Tolerance Level

# %%
max_error = 0.04

# %%
segments = bottomupsegment(Log1['Delta_Log_Return'], regression,sumsquared_error, max_error)
draw_plot(Log1['Delta_Log_Return'],"Delta_Log_Return_Error_Tolerance Level of 0.04%")
draw_segments(segments)
# Out:
# <ipython-input-24-794041481bfc>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   (p,residuals,rank,s) = lstsq(A,y)

# %%
max_error = 0.1

# %%
segments = bottomupsegment(Log1['Delta_Log_Return'], regression,sumsquared_error, max_error)
draw_plot(Log1['Delta_Log_Return'],"Delta_Log_Return_Error_Tolerance Level of 0.1%")
draw_segments(segments)
# Out:
# <ipython-input-24-794041481bfc>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   (p,residuals,rank,s) = lstsq(A,y)

# %%
max_error = 0.25

# %%
segments = bottomupsegment(Log1['Delta_Log_Return'], regression,sumsquared_error, max_error)
draw_plot(Log1['Delta_Log_Return'],"Delta_Log_Return_Error_Tolerance Level of 0.25%")
draw_segments(segments)
# Out:
# <ipython-input-24-794041481bfc>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   (p,residuals,rank,s) = lstsq(A,y)

# %% [markdown]
# # Jet_Blue_Error_Tolerance Level

# %%
max_error = 0.04

# %%
segments = bottomupsegment(Log1['Jet_Blue_Log Return'], regression,sumsquared_error, max_error)
draw_plot(Log1['Jet_Blue_Log Return'],"Jet_Blue_Error_Tolerance Level of 0.04%")
draw_segments(segments)
# Out:
# <ipython-input-24-794041481bfc>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   (p,residuals,rank,s) = lstsq(A,y)

# %%
max_error = 0.1

# %%
segments = bottomupsegment(Log1['Jet_Blue_Log Return'], regression,sumsquared_error, max_error)
draw_plot(Log1['Jet_Blue_Log Return'],"Jet_Blue_Error_Tolerance Level of 0.1%")
draw_segments(segments)
# Out:
# <ipython-input-24-794041481bfc>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   (p,residuals,rank,s) = lstsq(A,y)

# %%
max_error = 0.25

# %%
segments = bottomupsegment(Log1['Jet_Blue_Log Return'], regression,sumsquared_error, max_error)
draw_plot(Log1['Jet_Blue_Log Return'],"Jet_Blue_Error_Tolerance Level of 0.25%")
draw_segments(segments)
# Out:
# <ipython-input-24-794041481bfc>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   (p,residuals,rank,s) = lstsq(A,y)

# %% [markdown]
# # "United_Airline_Error_Tolerance Level"

# %%
max_error = 0.04

# %%
segments = bottomupsegment(Log1['United_Airline_Log Return'], regression,sumsquared_error, max_error)
draw_plot(Log1['United_Airline_Log Return'],"United_Airline_Error_Tolerance Level of 0.04%")
draw_segments(segments)
# Out:
# <ipython-input-24-794041481bfc>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   (p,residuals,rank,s) = lstsq(A,y)

# %%
max_error = 0.1

# %%
segments = bottomupsegment(Log1['United_Airline_Log Return'], regression,sumsquared_error, max_error)
draw_plot(Log1['United_Airline_Log Return'],"United_Airline_Error_Tolerance Level of 0.1%")
draw_segments(segments)
# Out:
# <ipython-input-24-794041481bfc>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   (p,residuals,rank,s) = lstsq(A,y)

# %%
max_error = 0.25

# %%
segments = bottomupsegment(Log1['United_Airline_Log Return'], regression,sumsquared_error, max_error)
draw_plot(Log1['United_Airline_Log Return'],"United_Airline_Error_Tolerance Level of 0.25%")
draw_segments(segments)
# Out:
# <ipython-input-24-794041481bfc>:7: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   (p,residuals,rank,s) = lstsq(A,y)

# %%
TimeSeries
# Out:
#      American_Airline_Close  Delta_Close  Jet_Blue_Close  \
# 0                 32.480000    50.090000       16.200001
# 1                 30.059999    45.610001       15.930000
# 2                 32.040001    47.790001       16.549999
# 3                 32.950001    47.849998       16.690001
# 4                 32.419998    47.470001       16.850000
# ..                      ...          ...             ...
# 751               18.260000    39.299999       14.670000
# 752               18.170000    39.000000       14.560000
# 753               18.540001    39.630001       14.680000
# 754               18.049999    39.160000       14.380000
# 755               18.070000    39.040001       14.240000
#
#      United_Airline_Close  LogReturn_American_Airline  Delta_Log_Return  \
# 0               84.180000                         NaN               NaN
# 1               80.000000                   -0.077429         -0.093694
# ...

# %%
TimeSeries3
# Out:
#      American_Airline_zscore  Delta_zscore  Jet_Blue_zscore  \
# 0                        NaN           NaN              NaN
# 1                  -0.461642     -1.801497        -1.185222
# 2                   1.064247      1.517449         0.800158
# 3                   0.238490      0.676457         0.177174
# 4                   0.269488     -0.362854        -0.222720
# ..                       ...           ...              ...
# 751                 0.061544      0.018253         0.179026
# 752                -0.204114     -0.097871        -0.133223
# 753                 0.232502      0.492026         0.383779
# 754                -0.568211     -0.611251        -0.423062
# 755                -0.266741      0.044281        -0.140112
#
#      United_Airline_zscore
# 0                      NaN
# 1                -2.769467
# 2                 1.394742
# 3                 0.047009
# 4                -0.226715
# ..                     ...
# 751               0.138382
# ...

# %%
Log1
# Out:
#      LogReturn_American_Airline  Delta_Log_Return  Jet_Blue_Log Return  \
# 1                     -0.077429         -0.093694            -0.016807
# 2                      0.063790          0.046689             0.038182
# 3                      0.028006          0.001255             0.008424
# 4                     -0.016216         -0.007973             0.009541
# 5                      0.030379          0.020847             0.022301
# ..                          ...               ...                  ...
# 751                    0.000000          0.004335             0.002047
# 752                   -0.004941         -0.007663            -0.007527
# 753                    0.020159          0.016025             0.008208
# 754                   -0.026785         -0.011931            -0.020648
# 755                    0.001107         -0.003069            -0.009783
#
#      United_Airline_Log Return
# 1                    -0.050931
# 2                     0.032951
# ...

# %% [markdown]
# # Normalize to z-score
#
#
#
# Data['DT1'] = (Data['DT1'] - Data['DT1'].mean())/Data['DT1'].std(ddof=0)
# Data['DT2'] = (Data['DT2'] - Data['DT2'].mean())/Data['DT2'].std(ddof=0)
# Data['DT3'] = (Data['DT3'] - Data['DT3'].mean())/Data['DT3'].std(ddof=0)
# Data['GT'] = (Data['GT'] - Data['GT'].mean())/Data['GT'].std(ddof=0)
#
# Data

# %% [markdown]
# Data = Log1.rename(columns={"LogReturn_American_Airline": "GT", "Delta_Log_Return": "DT1","Jet_Blue_Log Return":"DT2","United_Airline_Log Return":"DT3"})
# #x = Log1.rename(index={1: "GT", 2: "DT1", 3: "DT2",4:'DT3'})
# #Data

# %% [markdown]
# # Prediction

# %%
## Original Data

Data = TimeSeries.rename(columns={"American_Airline_Close": "GT", "Delta_Close": "DT1","Jet_Blue_Close":"DT2","United_Airline_Close":"DT3"})
Data
# Out:
#             GT        DT1        DT2        DT3  LogReturn_American_Airline  \
# 0    32.480000  50.090000  16.200001  84.180000                         NaN
# 1    30.059999  45.610001  15.930000  80.000000                   -0.077429
# 2    32.040001  47.790001  16.549999  82.680000                    0.063790
# 3    32.950001  47.849998  16.690001  83.230003                    0.028006
# 4    32.419998  47.470001  16.850000  82.379997                   -0.016216
# ..         ...        ...        ...        ...                         ...
# 751  18.260000  39.299999  14.670000  44.869999                    0.000000
# 752  18.170000  39.000000  14.560000  44.580002                   -0.004941
# 753  18.540001  39.630001  14.680000  45.270000                    0.020159
# 754  18.049999  39.160000  14.380000  44.430000                   -0.026785
# 755  18.070000  39.040001  14.240000  44.130001                    0.001107
#
# ...

# %%
## Normalise data

Data2 = Log1.rename(columns={"LogReturn_American_Airline": "GT", "Delta_Log_Return": "DT1","Jet_Blue_Log Return":"DT2","United_Airline_Log Return":"DT3"})
Data2
# Out:
#            GT       DT1       DT2       DT3
# 1   -0.077429 -0.093694 -0.016807 -0.050931
# 2    0.063790  0.046689  0.038182  0.032951
# 3    0.028006  0.001255  0.008424  0.006630
# 4   -0.016216 -0.007973  0.009541 -0.010265
# 5    0.030379  0.020847  0.022301  0.016613
# ..        ...       ...       ...       ...
# 751  0.000000  0.004335  0.002047  0.006708
# 752 -0.004941 -0.007663 -0.007527 -0.006484
# 753  0.020159  0.016025  0.008208  0.015359
# 754 -0.026785 -0.011931 -0.020648 -0.018730
# 755  0.001107 -0.003069 -0.009783 -0.006775
#
# [755 rows x 4 columns]

# %%
Data2['G(t+1)'] = Data2['GT'].shift(-1)
print (Data2)
Data_shift = Data2.drop(Data2.index[len(Data2)-1])
Data_shift
# Out:
#            GT       DT1       DT2       DT3    G(t+1)
# 1   -0.077429 -0.093694 -0.016807 -0.050931  0.063790
# 2    0.063790  0.046689  0.038182  0.032951  0.028006
# 3    0.028006  0.001255  0.008424  0.006630 -0.016216
# 4   -0.016216 -0.007973  0.009541 -0.010265  0.030379
# 5    0.030379  0.020847  0.022301  0.016613 -0.042169
# ..        ...       ...       ...       ...       ...
# 751  0.000000  0.004335  0.002047  0.006708 -0.004941
# 752 -0.004941 -0.007663 -0.007527 -0.006484  0.020159
# 753  0.020159  0.016025  0.008208  0.015359 -0.026785
# 754 -0.026785 -0.011931 -0.020648 -0.018730  0.001107
# 755  0.001107 -0.003069 -0.009783 -0.006775       NaN
#
# [755 rows x 5 columns]
#            GT       DT1       DT2       DT3    G(t+1)
# 1   -0.077429 -0.093694 -0.016807 -0.050931  0.063790
# 2    0.063790  0.046689  0.038182  0.032951  0.028006
# 3    0.028006  0.001255  0.008424  0.006630 -0.016216
# 4   -0.016216 -0.007973  0.009541 -0.010265  0.030379
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt



import statsmodels.api as sm
from statsmodels.stats import diagnostic as diag
from statsmodels.stats.outliers_influence import variance_inflation_factor



from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
X = Data_shift[{'GT','DT1','DT2','DT3'}]
Y = Data_shift['G(t+1)']

# %%
X_train,X_test,y_train,y_test= train_test_split(X,Y, test_size=0.33, random_state=0)

# %%
regression_model = LinearRegression()

# %%
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
intercept = regression_model.intercept_

# %%
coefficent = regression_model.coef_

# %%
print("The intercept for our model is {:}".format(intercept))
# Out:
# The intercept for our model is -0.0012793643386661002

# %%
r2 = regression_model.score(X_test, y_test)
print('Predictive Accuracy(R-Squraed):',r2)
# Out:
# Predictive Accuracy(R-Squraed): -0.02485268695412568

# %%
Data_shift
# Out:
#            GT       DT1       DT2       DT3    G(t+1)  Prediction
# 1   -0.077429 -0.093694 -0.016807 -0.050931  0.063790  545.974520
# 2    0.063790  0.046689  0.038182  0.032951  0.028006 -353.228540
# 3    0.028006  0.001255  0.008424  0.006630 -0.016216  -71.072701
# 4   -0.016216 -0.007973  0.009541 -0.010265  0.030379  110.043252
# 5    0.030379  0.020847  0.022301  0.016613 -0.042169 -178.086995
# ..        ...       ...       ...       ...       ...         ...
# 750  0.007697  0.015712  0.008230  0.014464  0.000000 -155.049406
# 751  0.000000  0.004335  0.002047  0.006708 -0.004941  -71.915358
# 752 -0.004941 -0.007663 -0.007527 -0.006484  0.020159   69.506400
# 753  0.020159  0.016025  0.008208  0.015359 -0.026785 -164.649846
# 754 -0.026785 -0.011931 -0.020648 -0.018730  0.001107  200.775539
#
# [754 rows x 6 columns]

# %%
for coef in zip(X.columns, regression_model.coef_):
    print("The Coefficient for {} is {:}".format(coef[0],coef[1]))
# Out:
# The Coefficient for DT1 is -0.047182514434312886
# The Coefficient for DT2 is 0.18321769930107962
# The Coefficient for DT3 is -0.17202647701629686
# The Coefficient for GT is 0.08539660547376093

# %%
Data_shift['Prediction']=(-0.0012+(Data_shift['GT']* 0.0853)+(Data_shift['DT1']*-0.0471+(Data_shift['DT2']* 0.1832)+(Data_shift['DT3']* -0.1720)
# Out:
#   File "<ipython-input-122-c76578f7d581>", line 1
#     Data_shift['Prediction'] =(-0.0012+(Data_shift['GT']* 0.0853)+(Data_shift['DT1']*-0.0471+(Data_shift['DT2']* 0.1832)+(Data_shift['DT3']* -0.1720)
#                                                                                                                                                      ^
# SyntaxError: unexpected EOF while parsing

# %%
plt.figure(figsize=(8,6))
plt.title("(g(t);g(t +1))")
plt.scatter(Data_shift['GT'],Data_shift['G(t+1)'])

# %%
plt.figure(figsize=(8,6))
plt.title("Forecasting")
plt.scatter(Data_shift['GT'],Data_shift['Prediction'])

# %%
#Visualization of residuals
residuals =Data_shift['GT']-Data_shift['Prediction']
plt.scatter(residuals,Data_shift['Prediction'])
plt.title("(g(t) g(t) the residual")
plt.ylabel("Prediction")
plt.xlabel("Residuals")
print(residuals)
plt.show()
# Out:
# 1     -546.051949
# 2      353.292330
# 3       71.100707
# 4     -110.059468
# 5      178.117374
#           ...
# 750    155.057103
# 751     71.915358
# 752    -69.511341
# 753    164.670004
# 754   -200.802324
# Length: 754, dtype: float64

# %%
from sklearn import metrics
print('The Absoluate Mean Error:', metrics.mean_absolute_error(Data_shift['GT'],Data_shift['Prediction']))
print('Mean Squared prediction error :', metrics.mean_squared_error(Data_shift['GT'],Data_shift['Prediction']))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Data_shift['GT'],Data_shift['Prediction'])))
# Out:
# The Absoluate Mean Error: 270.1274288429892
# Mean Squared prediction error : 205510.75578851084
# Root Mean Squared Error: 453.3329414332372
